# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
import pickle
with open('rf_model.pkl','rb') as f:
    model=pickle.load(f)

# %%
model
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=10,
#                        n_estimators=65)

# %%
out = model.predict([[10,3,2]])
out
# Out:
# array([4], dtype=int64)

# %%
# 4 -- rated outstanding

# %%
model.predict([[15,2.5,4]])
# Out:
# array([2], dtype=int64)

# %%
# 2 -- rated good

# %%
model.predict([[8,2,5]])
# Out:
# array([2], dtype=int64)

# %%
# 2 -- rated good

# %%
model.predict([[3,1,6]])
# Out:
# array([2], dtype=int64)

# %%
# 2 -- rated good
